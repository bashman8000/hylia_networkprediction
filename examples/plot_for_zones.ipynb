# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
import warnings
import itertools
from datetime import datetime
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
# plt.rcParams["font.family"] = "sans-serif"
print('hello')
# Out:
# hello

# %%
pwd
# Out:
# '/Users/bashirm/Documents/GitHub/daphne/time-series-prediction/2010_1hourdata_per_zone_links'

# %%
df = pd.read_csv("trans_atl_links.csv")

# %%
df.head()
# Out:
#                Time  LOND_NEWY_in  LOND_NEWY_out  AMST_BOST_in  AMST_BOST_out  \
# 0  01/01/2018 08:00  1.109243e+09   8.683116e+09  3.926408e+09   6.210077e+09
# 1  01/01/2018 09:00  1.242256e+09   5.181239e+09  2.726693e+09   5.627768e+09
# 2  01/01/2018 10:00  2.006322e+09   1.224286e+10  4.623652e+09   6.190882e+09
# 3  01/01/2018 11:00  1.073181e+09   4.717642e+09  2.483065e+09   2.286046e+09
# 4  01/01/2018 12:00  8.645069e+08   1.987249e+09  1.020563e+09   2.556964e+09
#
#    AOFA_LOND_in  AOFA_LOND_out  CERN-513_WASH_in  CERN-513_WASH_out
# 0  2.952571e+10    32127050406      9.575782e+08       7.241651e+09
# 1  2.323105e+10    30542821342      1.846840e+09       3.695484e+09
# 2  3.053876e+10    27252911164      1.947976e+09       5.325143e+09
# 3  2.570215e+10    28311807743      2.217494e+09       2.194284e+09
# 4  2.445649e+10    19851990236      1.115394e+09       3.096373e+09

# %%
df.isnull().sum()
# Out:
# Time                 0
# LOND_NEWY_in         0
# LOND_NEWY_out        0
# AMST_BOST_in         0
# AMST_BOST_out        0
# AOFA_LOND_in         0
# AOFA_LOND_out        0
# CERN-513_WASH_in     0
# CERN-513_WASH_out    0
# dtype: int64

# %%
df['Time'] =  pd.to_datetime(df['Time'])

# %%
df = df.set_index('Time')

# %%
df.plot(figsize=(12, 8))
plt.rcParams.update({'font.size':15})
plt.xlabel('Date')
plt.ylabel('Bandwidth (GB)')
#plt.title('Speed Over Days In A Month')
plt.rcParams["font.weight"] = "bold"
plt.show()
